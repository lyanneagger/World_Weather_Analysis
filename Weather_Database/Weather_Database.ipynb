# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count +=1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | barmer
# Processing Record 2 of Set 1 | mataura
# Processing Record 3 of Set 1 | sept-iles
# Processing Record 4 of Set 1 | upernavik
# Processing Record 5 of Set 1 | charleston
# Processing Record 6 of Set 1 | khatanga
# Processing Record 7 of Set 1 | hobart
# Processing Record 8 of Set 1 | butaritari
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | rikitea
# Processing Record 11 of Set 1 | iquique
# Processing Record 12 of Set 1 | chernyshkovskiy
# Processing Record 13 of Set 1 | chokurdakh
# Processing Record 14 of Set 1 | roma
# Processing Record 15 of Set 1 | georgetown
# Processing Record 16 of Set 1 | kieta
# Processing Record 17 of Set 1 | bluff
# Processing Record 18 of Set 1 | tasiilaq
# Processing Record 19 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 20 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 21 of Set 1 | westport
# Processing Record 22 of Set 1 | taoudenni
# Processing Record 23 of Set 1 | nardaran
# Processing Record 24 of Set 1 | cam ranh
# Processing Record 25 of Set 1 | saint pete beach
# Processing Record 26 of Set 1 | castro
# Processing Record 27 of Set 1 | airai
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | kaitangata
# Processing Record 31 of Set 1 | thompson
# Processing Record 32 of Set 1 | vaini
# Processing Record 33 of Set 1 | mackay
# Processing Record 34 of Set 1 | albany
# Processing Record 35 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 36 of Set 1 | te anau
# Processing Record 37 of Set 1 | jiuquan
# Processing Record 38 of Set 1 | mayumba
# Processing Record 39 of Set 1 | bengkulu
# Processing Record 40 of Set 1 | parvatipuram
# Processing Record 41 of Set 1 | pitimbu
# Processing Record 42 of Set 1 | tuatapere
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | inirida
# Processing Record 45 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 1 | east london
# Processing Record 47 of Set 1 | seoul
# Processing Record 48 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 49 of Set 1 | itarema
# Processing Record 50 of Set 1 | kruisfontein
# Processing Record 1 of Set 2 | laishevo
# Processing Record 2 of Set 2 | ornskoldsvik
# Processing Record 3 of Set 2 | college
# Processing Record 4 of Set 2 | mount gambier
# Processing Record 5 of Set 2 | kununurra
# Processing Record 6 of Set 2 | jundubah
# City not found. Skipping...
# Processing Record 7 of Set 2 | tura
# Processing Record 8 of Set 2 | emerald
# Processing Record 9 of Set 2 | sangar
# Processing Record 10 of Set 2 | omboue
# Processing Record 11 of Set 2 | leningradskiy
# Processing Record 12 of Set 2 | arraial do cabo
# Processing Record 13 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 14 of Set 2 | port alfred
# Processing Record 15 of Set 2 | laguna beach
# Processing Record 16 of Set 2 | camacha
# Processing Record 17 of Set 2 | shimoda
# Processing Record 18 of Set 2 | grindavik
# Processing Record 19 of Set 2 | jackson
# Processing Record 20 of Set 2 | nipawin
# Processing Record 21 of Set 2 | jalu
# Processing Record 22 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 2 | seredka
# Processing Record 24 of Set 2 | omsukchan
# Processing Record 25 of Set 2 | jamestown
# Processing Record 26 of Set 2 | daru
# Processing Record 27 of Set 2 | victoria
# Processing Record 28 of Set 2 | guerrero negro
# Processing Record 29 of Set 2 | srednekolymsk
# Processing Record 30 of Set 2 | dikson
# Processing Record 31 of Set 2 | kirensk
# Processing Record 32 of Set 2 | puerto ayora
# Processing Record 33 of Set 2 | kavieng
# Processing Record 34 of Set 2 | katete
# Processing Record 35 of Set 2 | vila franca do campo
# Processing Record 36 of Set 2 | punta arenas
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | husavik
# Processing Record 39 of Set 2 | fougamou
# Processing Record 40 of Set 2 | nicoya
# Processing Record 41 of Set 2 | kedrovyy
# Processing Record 42 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 43 of Set 2 | bonthe
# Processing Record 44 of Set 2 | hami
# Processing Record 45 of Set 2 | lakhimpur
# Processing Record 46 of Set 2 | cape town
# Processing Record 47 of Set 2 | saskylakh
# Processing Record 48 of Set 2 | syracuse
# Processing Record 49 of Set 2 | saint anthony
# Processing Record 50 of Set 2 | progreso
# Processing Record 1 of Set 3 | odienne
# Processing Record 2 of Set 3 | rawson
# Processing Record 3 of Set 3 | sao filipe
# Processing Record 4 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 3 | brigantine
# Processing Record 6 of Set 3 | mengyin
# Processing Record 7 of Set 3 | vao
# Processing Record 8 of Set 3 | mayo
# Processing Record 9 of Set 3 | ucluelet
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | tambacounda
# Processing Record 12 of Set 3 | cabo san lucas
# Processing Record 13 of Set 3 | nouadhibou
# Processing Record 14 of Set 3 | ahuimanu
# Processing Record 15 of Set 3 | kamenka
# Processing Record 16 of Set 3 | hithadhoo
# Processing Record 17 of Set 3 | bay roberts
# Processing Record 18 of Set 3 | alekseyevka
# Processing Record 19 of Set 3 | nara
# Processing Record 20 of Set 3 | green river
# Processing Record 21 of Set 3 | saint george
# Processing Record 22 of Set 3 | qui nhon
# Processing Record 23 of Set 3 | new norfolk
# Processing Record 24 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 3 | arman
# Processing Record 26 of Set 3 | salalah
# Processing Record 27 of Set 3 | srivardhan
# Processing Record 28 of Set 3 | cherskiy
# Processing Record 29 of Set 3 | hilo
# Processing Record 30 of Set 3 | clyde river
# Processing Record 31 of Set 3 | vila
# Processing Record 32 of Set 3 | deputatskiy
# Processing Record 33 of Set 3 | nantucket
# Processing Record 34 of Set 3 | umm ruwabah
# City not found. Skipping...
# Processing Record 35 of Set 3 | aykhal
# Processing Record 36 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 37 of Set 3 | severo-kurilsk
# Processing Record 38 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 39 of Set 3 | nosy varika
# Processing Record 40 of Set 3 | bambous virieux
# Processing Record 41 of Set 3 | dezful
# Processing Record 42 of Set 3 | el cobre
# Processing Record 43 of Set 3 | kudahuvadhoo
# Processing Record 44 of Set 3 | asau
# Processing Record 45 of Set 3 | jha jha
# Processing Record 46 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 3 | chapais
# Processing Record 48 of Set 3 | bubaque
# Processing Record 49 of Set 3 | alyangula
# Processing Record 50 of Set 3 | ballina
# Processing Record 1 of Set 4 | pskent
# City not found. Skipping...
# Processing Record 2 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 4 | cidreira
# Processing Record 4 of Set 4 | saint-philippe
# Processing Record 5 of Set 4 | bredasdorp
# Processing Record 6 of Set 4 | bethel
# Processing Record 7 of Set 4 | tripoli
# Processing Record 8 of Set 4 | temaraia
# City not found. Skipping...
# Processing Record 9 of Set 4 | santa margherita ligure
# Processing Record 10 of Set 4 | nikolskoye
# Processing Record 11 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | zhigansk
# Processing Record 14 of Set 4 | isangel
# Processing Record 15 of Set 4 | oktyabrskiy
# Processing Record 16 of Set 4 | lata
# Processing Record 17 of Set 4 | ishige
# Processing Record 18 of Set 4 | iskateley
# Processing Record 19 of Set 4 | kenai
# Processing Record 20 of Set 4 | kloulklubed
# Processing Record 21 of Set 4 | bismarck
# Processing Record 22 of Set 4 | brae
# Processing Record 23 of Set 4 | mora
# Processing Record 24 of Set 4 | lorengau
# Processing Record 25 of Set 4 | alofi
# Processing Record 26 of Set 4 | atuona
# Processing Record 27 of Set 4 | morro bay
# Processing Record 28 of Set 4 | kamaishi
# Processing Record 29 of Set 4 | dali
# Processing Record 30 of Set 4 | dunedin
# Processing Record 31 of Set 4 | mar del plata
# Processing Record 32 of Set 4 | lubumbashi
# Processing Record 33 of Set 4 | coquimbo
# Processing Record 34 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 35 of Set 4 | tiznit
# Processing Record 36 of Set 4 | visby
# Processing Record 37 of Set 4 | pineville
# Processing Record 38 of Set 4 | aransas pass
# Processing Record 39 of Set 4 | kapaa
# Processing Record 40 of Set 4 | vyshneve
# Processing Record 41 of Set 4 | namie
# Processing Record 42 of Set 4 | santa cruz
# Processing Record 43 of Set 4 | wattegama
# Processing Record 44 of Set 4 | narsaq
# Processing Record 45 of Set 4 | babstovo
# Processing Record 46 of Set 4 | katobu
# Processing Record 47 of Set 4 | vanimo
# Processing Record 48 of Set 4 | buenos aires
# Processing Record 49 of Set 4 | kokopo
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | port augusta
# Processing Record 2 of Set 5 | mrirt
# City not found. Skipping...
# Processing Record 3 of Set 5 | chakulia
# Processing Record 4 of Set 5 | mendahara
# City not found. Skipping...
# Processing Record 5 of Set 5 | egvekinot
# Processing Record 6 of Set 5 | mahebourg
# Processing Record 7 of Set 5 | padang
# Processing Record 8 of Set 5 | yulara
# Processing Record 9 of Set 5 | barrancabermeja
# Processing Record 10 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 5 | sao gabriel da cachoeira
# Processing Record 12 of Set 5 | atar
# Processing Record 13 of Set 5 | port macquarie
# Processing Record 14 of Set 5 | japura
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | manggar
# Processing Record 17 of Set 5 | burgersdorp
# Processing Record 18 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 5 | iqaluit
# Processing Record 20 of Set 5 | kiunga
# Processing Record 21 of Set 5 | misratah
# Processing Record 22 of Set 5 | samarai
# Processing Record 23 of Set 5 | altamont
# Processing Record 24 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 5 | ampanihy
# Processing Record 26 of Set 5 | ahipara
# Processing Record 27 of Set 5 | kyabe
# Processing Record 28 of Set 5 | carnarvon
# Processing Record 29 of Set 5 | fairbanks
# Processing Record 30 of Set 5 | sioux lookout
# Processing Record 31 of Set 5 | port elizabeth
# Processing Record 32 of Set 5 | ribeira grande
# Processing Record 33 of Set 5 | tanda
# Processing Record 34 of Set 5 | souillac
# Processing Record 35 of Set 5 | sepatan
# Processing Record 36 of Set 5 | kirkwall
# Processing Record 37 of Set 5 | nanortalik
# Processing Record 38 of Set 5 | bilma
# Processing Record 39 of Set 5 | tuktoyaktuk
# Processing Record 40 of Set 5 | faanui
# Processing Record 41 of Set 5 | wanning
# Processing Record 42 of Set 5 | chiang mai
# Processing Record 43 of Set 5 | duluth
# Processing Record 44 of Set 5 | mayya
# Processing Record 45 of Set 5 | wanaka
# Processing Record 46 of Set 5 | korla
# Processing Record 47 of Set 5 | buin
# Processing Record 48 of Set 5 | ketchikan
# Processing Record 49 of Set 5 | chama
# Processing Record 50 of Set 5 | gurskoye
# City not found. Skipping...
# Processing Record 1 of Set 6 | vitre
# Processing Record 2 of Set 6 | tamandare
# Processing Record 3 of Set 6 | dongsheng
# Processing Record 4 of Set 6 | san francisco
# Processing Record 5 of Set 6 | selkirk
# Processing Record 6 of Set 6 | north bend
# Processing Record 7 of Set 6 | bontang
# Processing Record 8 of Set 6 | urusha
# Processing Record 9 of Set 6 | colesberg
# Processing Record 10 of Set 6 | tautira
# Processing Record 11 of Set 6 | kushima
# Processing Record 12 of Set 6 | namibe
# Processing Record 13 of Set 6 | keelung
# Processing Record 14 of Set 6 | ambilobe
# Processing Record 15 of Set 6 | gizo
# Processing Record 16 of Set 6 | ilulissat
# Processing Record 17 of Set 6 | buala
# Processing Record 18 of Set 6 | glubokoe
# City not found. Skipping...
# Processing Record 19 of Set 6 | domoni
# Processing Record 20 of Set 6 | labuan
# Processing Record 21 of Set 6 | tamworth
# Processing Record 22 of Set 6 | meulaboh
# Processing Record 23 of Set 6 | ishigaki
# Processing Record 24 of Set 6 | tiksi
# Processing Record 25 of Set 6 | torbay
# Processing Record 26 of Set 6 | cururupu
# Processing Record 27 of Set 6 | salym
# Processing Record 28 of Set 6 | khandyga
# Processing Record 29 of Set 6 | basudebpur
# Processing Record 30 of Set 6 | ostrovnoy
# Processing Record 31 of Set 6 | kangaatsiaq
# Processing Record 32 of Set 6 | acajutla
# Processing Record 33 of Set 6 | oga
# Processing Record 34 of Set 6 | shaumiani
# Processing Record 35 of Set 6 | teeli
# Processing Record 36 of Set 6 | hobyo
# Processing Record 37 of Set 6 | fort saint john
# City not found. Skipping...
# Processing Record 38 of Set 6 | palma del rio
# Processing Record 39 of Set 6 | the pas
# Processing Record 40 of Set 6 | the valley
# Processing Record 41 of Set 6 | sale
# Processing Record 42 of Set 6 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 6 | norton
# Processing Record 44 of Set 6 | washougal
# Processing Record 45 of Set 6 | mao
# Processing Record 46 of Set 6 | lampari
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | hailar
# Processing Record 49 of Set 6 | sainte-agathe-des-monts
# Processing Record 50 of Set 6 | alice springs
# Processing Record 1 of Set 7 | poum
# Processing Record 2 of Set 7 | puerto colombia
# Processing Record 3 of Set 7 | vila velha
# Processing Record 4 of Set 7 | uarini
# Processing Record 5 of Set 7 | barrow
# Processing Record 6 of Set 7 | tarakan
# Processing Record 7 of Set 7 | dubbo
# Processing Record 8 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 9 of Set 7 | haines junction
# Processing Record 10 of Set 7 | verkhnyaya inta
# Processing Record 11 of Set 7 | matagami
# Processing Record 12 of Set 7 | menongue
# Processing Record 13 of Set 7 | hualmay
# Processing Record 14 of Set 7 | provideniya
# Processing Record 15 of Set 7 | sur
# Processing Record 16 of Set 7 | carauari
# Processing Record 17 of Set 7 | kempele
# Processing Record 18 of Set 7 | kalabo
# Processing Record 19 of Set 7 | longyearbyen
# Processing Record 20 of Set 7 | kendal
# Processing Record 21 of Set 7 | nanga eboko
# Processing Record 22 of Set 7 | pangnirtung
# Processing Record 23 of Set 7 | pitkyaranta
# Processing Record 24 of Set 7 | chateauroux
# Processing Record 25 of Set 7 | luderitz
# Processing Record 26 of Set 7 | saldanha
# Processing Record 27 of Set 7 | soderhamn
# Processing Record 28 of Set 7 | tabou
# Processing Record 29 of Set 7 | colac
# Processing Record 30 of Set 7 | mehamn
# Processing Record 31 of Set 7 | cap malheureux
# Processing Record 32 of Set 7 | ancud
# Processing Record 33 of Set 7 | necochea
# Processing Record 34 of Set 7 | cayenne
# Processing Record 35 of Set 7 | miranorte
# City not found. Skipping...
# Processing Record 36 of Set 7 | jurado
# Processing Record 37 of Set 7 | calabozo
# Processing Record 38 of Set 7 | hamilton
# Processing Record 39 of Set 7 | constanza
# Processing Record 40 of Set 7 | hasaki
# Processing Record 41 of Set 7 | esperance
# Processing Record 42 of Set 7 | russell
# Processing Record 43 of Set 7 | chuy
# Processing Record 44 of Set 7 | najran
# Processing Record 45 of Set 7 | chachapoyas
# Processing Record 46 of Set 7 | lusambo
# Processing Record 47 of Set 7 | mpika
# Processing Record 48 of Set 7 | garmsar
# Processing Record 49 of Set 7 | zenzeli
# Processing Record 50 of Set 7 | winnemucca
# Processing Record 1 of Set 8 | banda aceh
# Processing Record 2 of Set 8 | beringovskiy
# Processing Record 3 of Set 8 | bahia blanca
# Processing Record 4 of Set 8 | bilibino
# Processing Record 5 of Set 8 | bongandanga
# Processing Record 6 of Set 8 | yeppoon
# Processing Record 7 of Set 8 | palana
# Processing Record 8 of Set 8 | yei
# Processing Record 9 of Set 8 | faya
# Processing Record 10 of Set 8 | manokwari
# Processing Record 11 of Set 8 | kabo
# Processing Record 12 of Set 8 | dharchula
# Processing Record 13 of Set 8 | sibolga
# Processing Record 14 of Set 8 | novodugino
# Processing Record 15 of Set 8 | peniche
# Processing Record 16 of Set 8 | ibra
# Processing Record 17 of Set 8 | san patricio
# Processing Record 18 of Set 8 | evensk
# Processing Record 19 of Set 8 | nadym
# Processing Record 20 of Set 8 | boa vista
# Processing Record 21 of Set 8 | catanduva
# Processing Record 22 of Set 8 | beausejour
# Processing Record 23 of Set 8 | monrovia
# Processing Record 24 of Set 8 | sola
# Processing Record 25 of Set 8 | asfi
# Processing Record 26 of Set 8 | ust-maya
# Processing Record 27 of Set 8 | oranjemund
# Processing Record 28 of Set 8 | hammerfest
# Processing Record 29 of Set 8 | sindor
# Processing Record 30 of Set 8 | ust-tsilma
# Processing Record 31 of Set 8 | sayat
# Processing Record 32 of Set 8 | gombong
# Processing Record 33 of Set 8 | launceston
# Processing Record 34 of Set 8 | amapa
# Processing Record 35 of Set 8 | margate
# Processing Record 36 of Set 8 | gweta
# Processing Record 37 of Set 8 | whitehorse
# Processing Record 38 of Set 8 | ambon
# Processing Record 39 of Set 8 | maku
# Processing Record 40 of Set 8 | cockburn harbour
# City not found. Skipping...
# Processing Record 41 of Set 8 | henties bay
# Processing Record 42 of Set 8 | moose factory
# Processing Record 43 of Set 8 | port hardy
# Processing Record 44 of Set 8 | rota
# Processing Record 45 of Set 8 | ponta do sol
# Processing Record 46 of Set 8 | mnogovershinnyy
# Processing Record 47 of Set 8 | otane
# Processing Record 48 of Set 8 | quixeramobim
# Processing Record 49 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 50 of Set 8 | komsomolskiy
# Processing Record 1 of Set 9 | port-gentil
# Processing Record 2 of Set 9 | vardo
# Processing Record 3 of Set 9 | vestmanna
# Processing Record 4 of Set 9 | viedma
# Processing Record 5 of Set 9 | san isidro
# Processing Record 6 of Set 9 | vestmannaeyjar
# Processing Record 7 of Set 9 | tigil
# Processing Record 8 of Set 9 | constitucion
# Processing Record 9 of Set 9 | pevek
# Processing Record 10 of Set 9 | stoyba
# City not found. Skipping...
# Processing Record 11 of Set 9 | weston
# Processing Record 12 of Set 9 | shirokiy
# Processing Record 13 of Set 9 | athens
# Processing Record 14 of Set 9 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 9 | klyuchi
# Processing Record 16 of Set 9 | zaysan
# Processing Record 17 of Set 9 | marsa matruh
# Processing Record 18 of Set 9 | caohe
# Processing Record 19 of Set 9 | panama city
# Processing Record 20 of Set 9 | half moon bay
# Processing Record 21 of Set 9 | sarakhs
# Processing Record 22 of Set 9 | severnyy
# Processing Record 23 of Set 9 | oktyabrskoye
# Processing Record 24 of Set 9 | ortona
# Processing Record 25 of Set 9 | baiyin
# Processing Record 26 of Set 9 | el alto
# Processing Record 27 of Set 9 | turukhansk
# Processing Record 28 of Set 9 | illapel
# Processing Record 29 of Set 9 | nha trang
# Processing Record 30 of Set 9 | kaseda
# Processing Record 31 of Set 9 | mangrol
# Processing Record 32 of Set 9 | presidente olegario
# Processing Record 33 of Set 9 | ajdabiya
# Processing Record 34 of Set 9 | baruun-urt
# Processing Record 35 of Set 9 | san felipe
# Processing Record 36 of Set 9 | notre-dame-du-lac
# Processing Record 37 of Set 9 | talnakh
# Processing Record 38 of Set 9 | qaanaaq
# Processing Record 39 of Set 9 | gabriel leyva solano
# Processing Record 40 of Set 9 | pisco
# Processing Record 41 of Set 9 | save
# Processing Record 42 of Set 9 | karamea
# City not found. Skipping...
# Processing Record 43 of Set 9 | bonfim
# Processing Record 44 of Set 9 | union
# Processing Record 45 of Set 9 | walvis bay
# Processing Record 46 of Set 9 | la ronge
# Processing Record 47 of Set 9 | bridlington
# Processing Record 48 of Set 9 | durres
# Processing Record 49 of Set 9 | lebu
# Processing Record 50 of Set 9 | vanavara
# Processing Record 1 of Set 10 | khonsa
# Processing Record 2 of Set 10 | teixoso
# Processing Record 3 of Set 10 | balsta
# Processing Record 4 of Set 10 | devils lake
# Processing Record 5 of Set 10 | kontagora
# Processing Record 6 of Set 10 | aquiraz
# Processing Record 7 of Set 10 | olafsvik
# Processing Record 8 of Set 10 | yeniseysk
# Processing Record 9 of Set 10 | reserva
# Processing Record 10 of Set 10 | port hedland
# Processing Record 11 of Set 10 | changli
# Processing Record 12 of Set 10 | dubrovka
# Processing Record 13 of Set 10 | praya
# Processing Record 14 of Set 10 | luena
# Processing Record 15 of Set 10 | longkou
# Processing Record 16 of Set 10 | port-cartier
# Processing Record 17 of Set 10 | sambava
# Processing Record 18 of Set 10 | tahe
# Processing Record 19 of Set 10 | jalesar
# Processing Record 20 of Set 10 | codrington
# Processing Record 21 of Set 10 | victoria point
# Processing Record 22 of Set 10 | kerouane
# Processing Record 23 of Set 10 | tecoanapa
# Processing Record 24 of Set 10 | saint-pierre
# Processing Record 25 of Set 10 | nouakchott
# Processing Record 26 of Set 10 | fallon
# Processing Record 27 of Set 10 | chicama
# Processing Record 28 of Set 10 | axim
# Processing Record 29 of Set 10 | sechelt
# Processing Record 30 of Set 10 | fare
# Processing Record 31 of Set 10 | magugu
# Processing Record 32 of Set 10 | waw
# Processing Record 33 of Set 10 | neiafu
# Processing Record 34 of Set 10 | sabha
# Processing Record 35 of Set 10 | quba
# Processing Record 36 of Set 10 | kimbe
# Processing Record 37 of Set 10 | cuamba
# Processing Record 38 of Set 10 | solovetskiy
# City not found. Skipping...
# Processing Record 39 of Set 10 | begun
# Processing Record 40 of Set 10 | naftah
# City not found. Skipping...
# Processing Record 41 of Set 10 | lancaster
# Processing Record 42 of Set 10 | bani walid
# Processing Record 43 of Set 10 | riyadh
# Processing Record 44 of Set 10 | loandjili
# Processing Record 45 of Set 10 | lompoc
# Processing Record 46 of Set 10 | gravdal
# Processing Record 47 of Set 10 | wageningen
# Processing Record 48 of Set 10 | katsuura
# Processing Record 49 of Set 10 | praia da vitoria
# Processing Record 50 of Set 10 | dzhusaly
# City not found. Skipping...
# Processing Record 1 of Set 11 | boyolangu
# Processing Record 2 of Set 11 | havoysund
# Processing Record 3 of Set 11 | kufstein
# Processing Record 4 of Set 11 | kalmunai
# Processing Record 5 of Set 11 | tucupita
# Processing Record 6 of Set 11 | teya
# Processing Record 7 of Set 11 | ferrol
# Processing Record 8 of Set 11 | shizunai
# Processing Record 9 of Set 11 | makakilo city
# Processing Record 10 of Set 11 | leh
# Processing Record 11 of Set 11 | geraldton
# Processing Record 12 of Set 11 | yueyang
# Processing Record 13 of Set 11 | sinnamary
# Processing Record 14 of Set 11 | vrangel
# Processing Record 15 of Set 11 | albion
# Processing Record 16 of Set 11 | flinders
# Processing Record 17 of Set 11 | tabas
# Processing Record 18 of Set 11 | harper
# Processing Record 19 of Set 11 | san remigio
# Processing Record 20 of Set 11 | yerbogachen
# Processing Record 21 of Set 11 | cilegon
# Processing Record 22 of Set 11 | lavrentiya
# Processing Record 23 of Set 11 | one hundred mile house
# City not found. Skipping...
# Processing Record 24 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 25 of Set 11 | zhitikara
# City not found. Skipping...
# Processing Record 26 of Set 11 | dandong
# Processing Record 27 of Set 11 | senneterre
# Processing Record 28 of Set 11 | puerto escondido
# Processing Record 29 of Set 11 | norman wells
# Processing Record 30 of Set 11 | dasoguz
# Processing Record 31 of Set 11 | doha
# Processing Record 32 of Set 11 | mmathubudukwane
# Processing Record 33 of Set 11 | barra do corda
# Processing Record 34 of Set 11 | hambantota
# Processing Record 35 of Set 11 | beloha
# Processing Record 36 of Set 11 | santo andre
# Processing Record 37 of Set 11 | palafrugell
# Processing Record 38 of Set 11 | aplahoue
# Processing Record 39 of Set 11 | aasiaat
# Processing Record 40 of Set 11 | talaya
# Processing Record 41 of Set 11 | sydney
# Processing Record 42 of Set 11 | beira
# Processing Record 43 of Set 11 | huadian
# Processing Record 44 of Set 11 | puerto leguizamo
# Processing Record 45 of Set 11 | shellbrook
# Processing Record 46 of Set 11 | dolbeau
# City not found. Skipping...
# Processing Record 47 of Set 11 | gdynia
# Processing Record 48 of Set 11 | ustka
# Processing Record 49 of Set 11 | gushikawa
# Processing Record 50 of Set 11 | rehoboth
# Processing Record 1 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 12 | abha
# Processing Record 3 of Set 12 | markova
# Processing Record 4 of Set 12 | nerchinskiy zavod
# Processing Record 5 of Set 12 | aswan
# Processing Record 6 of Set 12 | marawi
# Processing Record 7 of Set 12 | along
# Processing Record 8 of Set 12 | tigzirt
# Processing Record 9 of Set 12 | iracoubo
# Processing Record 10 of Set 12 | bundaberg
# Processing Record 11 of Set 12 | rajbiraj
# Processing Record 12 of Set 12 | saint-denis
# Processing Record 13 of Set 12 | el cope
# Processing Record 14 of Set 12 | puerto ayacucho
# Processing Record 15 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 16 of Set 12 | jiwani
# Processing Record 17 of Set 12 | awbari
# Processing Record 18 of Set 12 | prado
# Processing Record 19 of Set 12 | sorland
# Processing Record 20 of Set 12 | portland
# Processing Record 21 of Set 12 | san cristobal
# Processing Record 22 of Set 12 | nishihara
# Processing Record 23 of Set 12 | belawan
# Processing Record 24 of Set 12 | tilichiki
# Processing Record 25 of Set 12 | itupiranga
# Processing Record 26 of Set 12 | kutum
# Processing Record 27 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 12 | glenwood springs
# Processing Record 29 of Set 12 | batagay-alyta
# Processing Record 30 of Set 12 | sokolovo
# Processing Record 31 of Set 12 | kingaroy
# Processing Record 32 of Set 12 | khrebtovaya
# Processing Record 33 of Set 12 | trairi
# Processing Record 34 of Set 12 | puerto palomas
# Processing Record 35 of Set 12 | aksu
# Processing Record 36 of Set 12 | saint-louis
# Processing Record 37 of Set 12 | alta floresta
# Processing Record 38 of Set 12 | poronaysk
# Processing Record 39 of Set 12 | udachnyy
# Processing Record 40 of Set 12 | shaunavon
# Processing Record 41 of Set 12 | kupino
# Processing Record 42 of Set 12 | moyale
# Processing Record 43 of Set 12 | helmsdale
# Processing Record 44 of Set 12 | rypefjord
# Processing Record 45 of Set 12 | wajima
# Processing Record 46 of Set 12 | maldonado
# Processing Record 47 of Set 12 | keti bandar
# Processing Record 48 of Set 12 | porto velho
# Processing Record 49 of Set 12 | emmett
# Processing Record 50 of Set 12 | saint-augustin
# Processing Record 1 of Set 13 | bundibugyo
# Processing Record 2 of Set 13 | mount abu
# Processing Record 3 of Set 13 | dalby
# Processing Record 4 of Set 13 | kawalu
# Processing Record 5 of Set 13 | lysyanka
# Processing Record 6 of Set 13 | burnie
# Processing Record 7 of Set 13 | karratha
# Processing Record 8 of Set 13 | redcliffe
# Processing Record 9 of Set 13 | goderich
# Processing Record 10 of Set 13 | tonder
# Processing Record 11 of Set 13 | luneville
# Processing Record 12 of Set 13 | florianopolis
# Processing Record 13 of Set 13 | ongandjera
# Processing Record 14 of Set 13 | santa isabel do rio negro
# Processing Record 15 of Set 13 | inhambane
# Processing Record 16 of Set 13 | iquitos
# Processing Record 17 of Set 13 | djambala
# Processing Record 18 of Set 13 | gusau
# Processing Record 19 of Set 13 | sisimiut
# Processing Record 20 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 21 of Set 13 | xining
# Processing Record 22 of Set 13 | muroto
# Processing Record 23 of Set 13 | sao borja
# Processing Record 24 of Set 13 | pogar
# Processing Record 25 of Set 13 | derzhavinsk
# Processing Record 26 of Set 13 | barbate
# Processing Record 27 of Set 13 | ankang
# Processing Record 28 of Set 13 | gobabis
# Processing Record 29 of Set 13 | port blair
# Processing Record 30 of Set 13 | rantepao
# Processing Record 31 of Set 13 | slave lake
# Processing Record 32 of Set 13 | veraval
# Processing Record 33 of Set 13 | soyo
# Processing Record 34 of Set 13 | pemba
# Processing Record 35 of Set 13 | birjand
# Processing Record 36 of Set 13 | serowe
# Processing Record 37 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 38 of Set 13 | tezu
# Processing Record 39 of Set 13 | ossora
# Processing Record 40 of Set 13 | tommot
# Processing Record 41 of Set 13 | san quintin
# Processing Record 42 of Set 13 | edendale
# Processing Record 43 of Set 13 | gayny
# Processing Record 44 of Set 13 | volovo
# Processing Record 45 of Set 13 | utiroa
# City not found. Skipping...
# Processing Record 46 of Set 13 | tessalit
# Processing Record 47 of Set 13 | sabang
# Processing Record 48 of Set 13 | cruden bay
# City not found. Skipping...
# Processing Record 49 of Set 13 | qandahar
# City not found. Skipping...
# Processing Record 50 of Set 13 | conde
# Processing Record 1 of Set 14 | comodoro rivadavia
# Processing Record 2 of Set 14 | broken hill
# Processing Record 3 of Set 14 | acarau
# Processing Record 4 of Set 14 | rio gallegos
# Processing Record 5 of Set 14 | tabulbah
# City not found. Skipping...
# Processing Record 6 of Set 14 | bhadasar
# Processing Record 7 of Set 14 | bombay
# Processing Record 8 of Set 14 | doka
# Processing Record 9 of Set 14 | yamoussoukro
# Processing Record 10 of Set 14 | canutama
# Processing Record 11 of Set 14 | wewak
# Processing Record 12 of Set 14 | barentu
# Processing Record 13 of Set 14 | coihaique
# Processing Record 14 of Set 14 | mpanda
# Processing Record 15 of Set 14 | konakovo
# Processing Record 16 of Set 14 | concordia
# Processing Record 17 of Set 14 | dukat
# Processing Record 18 of Set 14 | hommelvik
# Processing Record 19 of Set 14 | pemangkat
# Processing Record 20 of Set 14 | saint-francois
# Processing Record 21 of Set 14 | san rafael
# Processing Record 22 of Set 14 | huarmey
# Processing Record 23 of Set 14 | noumea
# Processing Record 24 of Set 14 | taltal
# Processing Record 25 of Set 14 | elat
# Processing Record 26 of Set 14 | salinopolis
# Processing Record 27 of Set 14 | parrita
# Processing Record 28 of Set 14 | brownsville
# Processing Record 29 of Set 14 | san policarpo
# Processing Record 30 of Set 14 | shache
# Processing Record 31 of Set 14 | sokoto
# Processing Record 32 of Set 14 | carutapera
# Processing Record 33 of Set 14 | ler
# Processing Record 34 of Set 14 | remontnoye
# Processing Record 35 of Set 14 | tukrah
# Processing Record 36 of Set 14 | capao da canoa
# Processing Record 37 of Set 14 | waingapu
# Processing Record 38 of Set 14 | gat
# Processing Record 39 of Set 14 | bardiyah
# Processing Record 40 of Set 14 | humboldt
# Processing Record 41 of Set 14 | hervey bay
# Processing Record 42 of Set 14 | kirakira
# Processing Record 43 of Set 14 | inyonga
# Processing Record 44 of Set 14 | kozhva
# Processing Record 45 of Set 14 | kualakapuas
# Processing Record 46 of Set 14 | ayagoz
# Processing Record 47 of Set 14 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 49 of Set 14 | dolhasca
# Processing Record 50 of Set 14 | sarkand
# Processing Record 1 of Set 15 | puerto carreno
# Processing Record 2 of Set 15 | ekibastuz
# Processing Record 3 of Set 15 | aklavik
# Processing Record 4 of Set 15 | ocean springs
# Processing Record 5 of Set 15 | nizwa
# Processing Record 6 of Set 15 | kerema
# Processing Record 7 of Set 15 | eyrarbakki
# Processing Record 8 of Set 15 | tarauaca
# Processing Record 9 of Set 15 | khorixas
# Processing Record 10 of Set 15 | usinsk
# Processing Record 11 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 12 of Set 15 | bacolod
# Processing Record 13 of Set 15 | champawat
# Processing Record 14 of Set 15 | surt
# Processing Record 15 of Set 15 | guaratinga
# Processing Record 16 of Set 15 | san carlos de bariloche
# Processing Record 17 of Set 15 | coari
# Processing Record 18 of Set 15 | touros
# Processing Record 19 of Set 15 | port lincoln
# Processing Record 20 of Set 15 | lebedinyy
# Processing Record 21 of Set 15 | heilbron
# Processing Record 22 of Set 15 | berlevag
# Processing Record 23 of Set 15 | kahului
# Processing Record 24 of Set 15 | muisne
# Processing Record 25 of Set 15 | himora
# City not found. Skipping...
# Processing Record 26 of Set 15 | ville-marie
# Processing Record 27 of Set 15 | lagoa
# Processing Record 28 of Set 15 | pangai
# Processing Record 29 of Set 15 | storforshei
# Processing Record 30 of Set 15 | mbour
# Processing Record 31 of Set 15 | chemal
# Processing Record 32 of Set 15 | skagastrond
# City not found. Skipping...
# Processing Record 33 of Set 15 | lampazos de naranjo
# Processing Record 34 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 35 of Set 15 | ladario
# Processing Record 36 of Set 15 | kaeo
# Processing Record 37 of Set 15 | hamada
# Processing Record 38 of Set 15 | batagay
# Processing Record 39 of Set 15 | ginda
# Processing Record 40 of Set 15 | lensk
# Processing Record 41 of Set 15 | byron bay
# Processing Record 42 of Set 15 | bafoulabe
# Processing Record 43 of Set 15 | parakou
# Processing Record 44 of Set 15 | manaskent
# Processing Record 45 of Set 15 | ciudad bolivar
# Processing Record 46 of Set 15 | rolim de moura
# City not found. Skipping...
# Processing Record 47 of Set 15 | olinda
# Processing Record 48 of Set 15 | teapa
# Processing Record 49 of Set 15 | warrington
# Processing Record 50 of Set 15 | asyut
# Processing Record 1 of Set 16 | knysna
# Processing Record 2 of Set 16 | greenwood
# Processing Record 3 of Set 16 | puerto madryn
# Processing Record 4 of Set 16 | shelburne
# Processing Record 5 of Set 16 | gambela
# Processing Record 6 of Set 16 | gzhatsk
# City not found. Skipping...
# Processing Record 7 of Set 16 | totness
# Processing Record 8 of Set 16 | wilmington
# Processing Record 9 of Set 16 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 16 | barra patuca
# Processing Record 11 of Set 16 | douglas
# Processing Record 12 of Set 16 | hofn
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
print(len(city_data))
# Out:
# 701

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Barmer      IN  25.7500   71.3833     95.65        37           0
# 1     Mataura      NZ -46.1927  168.8643     49.48        94         100
# 2   Sept-Iles      CA  50.2001  -66.3821     55.83        68          20
# 3   Upernavik      GL  72.7868  -56.1549     30.24        74           3
# 4  Charleston      US  32.7766  -79.9309     77.02        96          90
# 5    Khatanga      RU  71.9667  102.5000     38.05        69         100
# 6      Hobart      AU -42.8794  147.3294     60.66        63          75
# 7  Butaritari      KI   3.0707  172.7902     83.28        67          99
# 8     Ushuaia      AR -54.8000  -68.3000     29.86        93          40
# 9     Rikitea      PF -23.1203 -134.9692     74.71        74          44
#
#    Wind Speed Current Description
# 0       12.57           clear sky
# 1        9.17          light rain
# 2        4.61          few clouds
# 3        8.61           clear sky
# 4        6.76     overcast clouds
# 5       11.90          light rain
# 6        8.01          light rain
# 7        2.93     overcast clouds
# 8        5.75    scattered clouds
# 9       13.04    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
